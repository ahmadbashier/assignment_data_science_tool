# %% [markdown]
# <H1> My Jupyter Notebook on IBM Watson Studio </H1>

# %% [markdown]
# __AHMAD BASHIER BIN ABD AZIZ__ <BR> I work as database administrator

# %% [markdown]
# _I am interested in data science because this career has a bright future. With data science, I can help to change the world_

# %% [markdown]
# ### Below code show how to calculate with variable function

# %%
a=1
b=3
c=a+b
print (c)
# Out:
# 4

# %% [markdown]
# ***
# |Number | State | Points |
# | --- | --- | --- |
# | 1 | Selangor | 43 |
# | 2 | Terengganu | 32 |
#
# [Gmail URL](http://www.gmail.com)
